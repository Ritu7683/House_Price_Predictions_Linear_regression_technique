# %%
#import pandas library for data manipulation
import pandas as pd
#import numpy as np to perform operations on array
import numpy as np
#import matplotlib as plt to perform data visualization
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Dataset.csv",encoding= 'unicode_escape')
df.head()
# Out:
# C:\Users\ritup\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (1,11,12,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                                  url            id  \
# 0  https://bj.lianjia.com/chengjiao/101084782030....  101084782030
# 1  https://bj.lianjia.com/chengjiao/101086012217....  101086012217
# 2  https://bj.lianjia.com/chengjiao/101086041636....  101086041636
# 3  https://bj.lianjia.com/chengjiao/101086406841....  101086406841
# 4  https://bj.lianjia.com/chengjiao/101086920653....  101086920653
#
#           Lng        Lat            Cid   tradeTime     DOM  followers  \
# 0  116.475489  40.019520  1111027376244  2016-08-09  1464.0        106
# 1  116.453917  39.881534  1111027381879  2016-07-28   903.0        126
# 2  116.561978  39.877145  1111040862969  2016-12-11  1271.0         48
# ...

# %%
#Analysis of Dataset

# %%
df.columns
# Out:
# Index(['url', 'id', 'Lng', 'Lat', 'Cid', 'tradeTime', 'DOM', 'followers',
#        'totalPrice', 'price', 'square', 'livingRoom', 'drawingRoom', 'kitchen',
#        'bathRoom', 'floor', 'buildingType', 'constructionTime',
#        'renovationCondition', 'buildingStructure', 'ladderRatio', 'elevator',
#        'fiveYearsProperty', 'subway', 'district', 'communityAverage'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  Lng            Lat           Cid            DOM  \
# count  318851.000000  318851.000000  3.188510e+05  160874.000000
# mean      116.418459      39.949591  1.129113e+12      28.822339
# std         0.112054       0.091983  2.363447e+12      50.237343
# min       116.072514      39.627030  1.111027e+12       1.000000
# 25%       116.344985      39.893200  1.111027e+12       1.000000
# 50%       116.416780      39.934527  1.111027e+12       6.000000
# 75%       116.477581      40.003018  1.111027e+12      37.000000
# max       116.732378      40.252758  1.114620e+15    1677.000000
#
#            followers     totalPrice          price         square  \
# count  318851.000000  318851.000000  318851.000000  318851.000000
# mean       16.731508     349.030201   43530.436379      83.240597
# std        34.209185     230.780778   21709.024204      37.234661
# min         0.000000       0.100000       1.000000       6.900000
# ...

# %%
df.shape
# Out:
# (318851, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318851 entries, 0 to 318850
# Data columns (total 26 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   url                  318851 non-null  object
#  1   id                   318851 non-null  object
#  2   Lng                  318851 non-null  float64
#  3   Lat                  318851 non-null  float64
#  4   Cid                  318851 non-null  int64
#  5   tradeTime            318851 non-null  object
#  6   DOM                  160874 non-null  float64
#  7   followers            318851 non-null  int64
#  8   totalPrice           318851 non-null  float64
#  9   price                318851 non-null  int64
#  10  square               318851 non-null  float64
#  11  livingRoom           318851 non-null  object
#  12  drawingRoom          318851 non-null  object
#  13  kitchen              318851 non-null  int64
#  14  bathRoom             318851 non-null  object
# ...

# %%
# Checking Null values
df.isnull().sum()*100/df.shape[0]
# Out:
# url                     0.000000
# id                      0.000000
# Lng                     0.000000
# Lat                     0.000000
# Cid                     0.000000
# tradeTime               0.000000
# DOM                    49.545713
# followers               0.000000
# totalPrice              0.000000
# price                   0.000000
# square                  0.000000
# livingRoom              0.000000
# drawingRoom             0.000000
# kitchen                 0.000000
# bathRoom                0.000000
# floor                   0.000000
# buildingType            0.633838
# constructionTime        0.000000
# renovationCondition     0.000000
# buildingStructure       0.000000
# ladderRatio             0.000000
# elevator                0.010036
# fiveYearsProperty       0.010036
# subway                  0.010036
# district                0.000000
# communityAverage        0.145209
# dtype: float64

# %%
#Droping the Null values and checking the presence of NULL values again
df = df.dropna(how='any',axis=0) 
df.isnull().sum()*100/df.shape[0]
# Out:
# url                    0.0
# id                     0.0
# Lng                    0.0
# Lat                    0.0
# Cid                    0.0
# tradeTime              0.0
# DOM                    0.0
# followers              0.0
# totalPrice             0.0
# price                  0.0
# square                 0.0
# livingRoom             0.0
# drawingRoom            0.0
# kitchen                0.0
# bathRoom               0.0
# floor                  0.0
# buildingType           0.0
# constructionTime       0.0
# renovationCondition    0.0
# buildingStructure      0.0
# ladderRatio            0.0
# elevator               0.0
# fiveYearsProperty      0.0
# subway                 0.0
# district               0.0
# communityAverage       0.0
# dtype: float64

# %%
#Droping the column totalPrice and url column
df.drop(['totalPrice','url','Cid','floor','id','tradeTime','constructionTime','ladderRatio',], axis=1, inplace=True)
df.head()
# Out:
#           Lng        Lat     DOM  followers  price  square livingRoom  \
# 0  116.475489  40.019520  1464.0        106  31680  131.00          2
# 1  116.453917  39.881534   903.0        126  43436  132.38          2
# 2  116.561978  39.877145  1271.0         48  52021  198.00          3
# 3  116.438010  40.076114   965.0        138  22202  134.00          3
# 4  116.428392  39.886229   927.0        286  48396   81.00          2
#
#   drawingRoom  kitchen bathRoom  buildingType  renovationCondition  \
# 0           1        1        1           1.0                    3
# 1           2        1        2           1.0                    4
# 2           2        1        3           4.0                    3
# 3           1        1        1           1.0                    1
# 4           1        1        1           4.0                    2
#
#    buildingStructure  elevator  fiveYearsProperty  subway  district  \
# 0                  6       1.0                0.0     1.0         7
# ...

# %%
#Let's see which is the most common house(living room wise)?
#sometimes it’s important for a builder to see which
#is the highest selling house type which enables the builder to make house based on that.

df['livingRoom'].value_counts().plot(kind='bar')
plt.title('number of livingRoom')
plt.xlabel('livingRoom')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
#Plotting sactter plot between livingRoom and price

plt.scatter(df.livingRoom,df.price)
plt.title("Living Room and Price ")
plt.xlabel("Living Room")
plt.ylabel("Price")
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
#Visualizing the location of the houses based on latitude and longitude.

plt.figure(figsize=(10,10))
sns.jointplot(x=df.Lat.values, y=df.Lng.values, size=10)
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
plt.show()
sns.despine
# Out:
# C:\Users\ritup\anaconda3\lib\site-packages\seaborn\axisgrid.py:2015: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
#How common factors such as square feets,latitude and longitutde are affecting the price of the houses ?

plt.scatter(df.price,df.square)
plt.title("Price vs Square Feet")
# Out:
# Text(0.5, 1.0, 'Price vs Square Feet')

# %%
plt.scatter(df.price,df.Lng)
plt.title("Price vs Longitutde")
# Out:
# Text(0.5, 1.0, 'Price vs Longitutde')

# %%
plt.scatter(df.price,df.square)
plt.title("Price vs Latitude")
# Out:
# Text(0.5, 1.0, 'Price vs Latitude')

# %%
#Plotting distplot for price attribute
sns.distplot(df['price'])
# Out:
# C:\Users\ritup\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
#this corr map is used to find the correlation between the attributes and the pricing so as to 
#get an idea about the relationship between them.

sns.heatmap(df.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
#Separating all the other attributes from the predicting attribute

x = df[['Lng','Lat','followers','square','livingRoom','buildingType','renovationCondition','buildingStructure','elevator','fiveYearsProperty','subway','district','communityAverage']]

# %%
#Assigning the predicting attribute into Y for model training

y = df[['price']]

# %%
#import model selection train test split for splitting the data into test and train for model validation.

from sklearn.model_selection import train_test_split

#import model selection train test split for splitting the data into test and train for model validation.

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
lreg = LinearRegression()

# %%
#training or fitting the train data into the model
lreg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lreg.intercept_)
# Out:
# [154108.74487886]

# %%
#examining the co-efficients of the fitted model.
lreg.coef_
# Out:
# array([[-2.13566214e+03,  2.22395217e+03,  8.93236024e+01,
#         -6.33663985e+01,  8.13637150e+02,  2.29444664e+02,
#          3.57595278e+03, -8.83180273e+01,  2.18668136e+02,
#         -4.48885511e+03,  6.35746716e+02, -5.63328260e+01,
#          7.87445003e-01]])

# %%
x_train.columns
# Out:
# Index(['Lng', 'Lat', 'followers', 'square', 'livingRoom', 'buildingType',
#        'renovationCondition', 'buildingStructure', 'elevator',
#        'fiveYearsProperty', 'subway', 'district', 'communityAverage'],
#       dtype='object')

# %%
cdf = pd.DataFrame(data=lreg.coef_.reshape(13,1),index=x_train.columns,columns=['Coeff'])

# %%
cdf
# Out:
#                            Coeff
# Lng                 -2135.662142
# Lat                  2223.952166
# followers              89.323602
# square                -63.366399
# livingRoom            813.637150
# buildingType          229.444664
# renovationCondition  3575.952783
# buildingStructure     -88.318027
# elevator              218.668136
# fiveYearsProperty   -4488.855111
# subway                635.746716
# district              -56.332826
# communityAverage        0.787445

# %%
predictions = lreg.predict(x_test)

# %%
#to visualise the predictions and the test Y 
plt.scatter(y_test,predictions)
# We can see in the graph that it's almost forming a linear line with less deviation

# %%
sns.distplot((y_test-predictions))
# Out:
# C:\Users\ritup\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 11573.435776717317
# MSE: 219093297.5729736
# RMSE: 14801.800484163188
